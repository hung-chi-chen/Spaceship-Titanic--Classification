# %%
import requests, json
import pandas as pd
import datetime as dt

# %%
# Q1. Find a data source with an API similar to the one we used in class (COVID-19 cases in Ontario).
# Q2. Describe briefly the data source: The Ontario Covid data shows the vacination status of incoming patient to ICU
# Q4. What type of authentication do you need to use? A: this is the open source data, so the Ontario data source did not require further authentication. 

resource_id = '274b819c-5d69-4539-a4db-f2950794138c'
#limit the data to 100 to prevent massive data which cause computer issues. 
limit = '100'

api_url = 'https://data.ontario.ca/en/api/3/action/datastore_search?resource_id={}&limit={}'.format(resource_id, limit)
api_url
# Out:
# 'https://data.ontario.ca/en/api/3/action/datastore_search?resource_id=274b819c-5d69-4539-a4db-f2950794138c&limit=100'

# %%
# Q3. Illustrate how to prepare a GET request to pull the data.
data = requests.get(api_url)

data = data.json()

# %%
data.keys()
# Out:
# dict_keys(['help', 'success', 'result'])

# %%
# displace the result & records
data['result']['records']
# Out:
# [{'_id': 1,
#   'date': '2021-08-10T00:00:00',
#   'icu_unvac': 22,
#   'icu_partial_vac': 3,
#   'icu_full_vac': 0,
#   'hospitalnonicu_unvac': 23,
#   'hospitalnonicu_partial_vac': 4,
#   'hospitalnonicu_full_vac': 11},
#  {'_id': 2,
#   'date': '2021-08-11T00:00:00',
#   'icu_unvac': 37,
#   'icu_partial_vac': 5,
#   'icu_full_vac': 2,
#   'hospitalnonicu_unvac': 34,
#   'hospitalnonicu_partial_vac': 7,
#   'hospitalnonicu_full_vac': 8},
#  {'_id': 3,
#   'date': '2021-08-12T00:00:00',
#   'icu_unvac': 45,
#   'icu_partial_vac': 5,
#   'icu_full_vac': 2,
#   'hospitalnonicu_unvac': 44,
#   'hospitalnonicu_partial_vac': 7,
#   'hospitalnonicu_full_vac': 9},
#  {'_id': 4,
#   'date': '2021-08-13T00:00:00',
#   'icu_unvac': 52,
#   'icu_partial_vac': 5,
#   'icu_full_vac': 3,
#   'hospitalnonicu_unvac': 65,
#   'hospitalnonicu_partial_vac': 6,
#   'hospitalnonicu_full_vac': 8},
#  {'_id': 5,
#   'date': '2021-08-14T00:00:00',
#   'icu_unvac': 53,
#   'icu_partial_vac': 4,
#   'icu_full_vac': 1,
#   'hospitalnonicu_unvac': 67,
#   'hospitalnonicu_partial_vac': 6,
#   'hospitalnonicu_full_vac': 11},
#  {'_id': 6,
#   'date': '2021-08-15T00:00:00',
#   'icu_unvac': 44,
#   'icu_partial_vac': 6,
#   'icu_full_vac': 1,
#   'hospitalnonicu_unvac': 58,
#   'hospitalnonicu_partial_vac': 4,
#   'hospitalnonicu_full_vac': 14},
#  {'_id': 7,
#   'date': '2021-08-16T00:00:00',
#   'icu_unvac': 48,
#   'icu_partial_vac': 9,
#   'icu_full_vac': 1,
#   'hospitalnonicu_unvac': 55,
#   'hospitalnonicu_partial_vac': 4,
#   'hospitalnonicu_full_vac': 17},
#  {'_id': 8,
#   'date': '2021-08-17T00:00:00',
#   'icu_unvac': 54,
#   'icu_partial_vac': 6,
#   'icu_full_vac': 3,
#   'hospitalnonicu_unvac': 67,
#   'hospitalnonicu_partial_vac': 8,
#   'hospitalnonicu_full_vac': 15},
#  {'_id': 9,
#   'date': '2021-08-18T00:00:00',
#   'icu_unvac': 58,
#   'icu_partial_vac': 6,
#   'icu_full_vac': 5,
#   'hospitalnonicu_unvac': 80,
#   'hospitalnonicu_partial_vac': 10,
#   'hospitalnonicu_full_vac': 16},
#  {'_id': 10,
#   'date': '2021-08-19T00:00:00',
#   'icu_unvac': 55,
#   'icu_partial_vac': 7,
#   'icu_full_vac': 6,
#   'hospitalnonicu_unvac': 76,
#   'hospitalnonicu_partial_vac': 9,
#   'hospitalnonicu_full_vac': 14},
#  {'_id': 11,
#   'date': '2021-08-20T00:00:00',
#   'icu_unvac': 68,
#   'icu_partial_vac': 7,
#   'icu_full_vac': 5,
#   'hospitalnonicu_unvac': 86,
#   'hospitalnonicu_partial_vac': 11,
#   'hospitalnonicu_full_vac': 20},
#  {'_id': 12,
#   'date': '2021-08-21T00:00:00',
#   'icu_unvac': 67,
#   'icu_partial_vac': 9,
#   'icu_full_vac': 7,
#   'hospitalnonicu_unvac': 103,
#   'hospitalnonicu_partial_vac': 9,
#   'hospitalnonicu_full_vac': 23},
#  {'_id': 13,
#   'date': '2021-08-22T00:00:00',
#   'icu_unvac': 59,
#   'icu_partial_vac': 9,
#   'icu_full_vac': 8,
#   'hospitalnonicu_unvac': 83,
#   'hospitalnonicu_partial_vac': 7,
#   'hospitalnonicu_full_vac': 24},
#  {'_id': 14,
#   'date': '2021-08-23T00:00:00',
#   'icu_unvac': 63,
#   'icu_partial_vac': 10,
#   'icu_full_vac': 8,
#   'hospitalnonicu_unvac': 102,
#   'hospitalnonicu_partial_vac': 9,
#   'hospitalnonicu_full_vac': 23},
#  {'_id': 15,
#   'date': '2021-08-24T00:00:00',
#   'icu_unvac': 71,
#   'icu_partial_vac': 10,
#   'icu_full_vac': 7,
#   'hospitalnonicu_unvac': 131,
#   'hospitalnonicu_partial_vac': 13,
#   'hospitalnonicu_full_vac': 28},
#  {'_id': 16,
#   'date': '2021-08-25T00:00:00',
#   'icu_unvac': 81,
#   'icu_partial_vac': 9,
#   'icu_full_vac': 9,
#   'hospitalnonicu_unvac': 137,
#   'hospitalnonicu_partial_vac': 11,
#   'hospitalnonicu_full_vac': 30},
#  {'_id': 17,
#   'date': '2021-08-26T00:00:00',
#   'icu_unvac': 89,
#   'icu_partial_vac': 9,
#   'icu_full_vac': 10,
#   'hospitalnonicu_unvac': 138,
#   'hospitalnonicu_partial_vac': 14,
#   'hospitalnonicu_full_vac': 31},
#  {'_id': 18,
#   'date': '2021-08-27T00:00:00',
#   'icu_unvac': 89,
#   'icu_partial_vac': 8,
#   'icu_full_vac': 9,
#   'hospitalnonicu_unvac': 141,
#   'hospitalnonicu_partial_vac': 16,
#   'hospitalnonicu_full_vac': 27},
#  {'_id': 19,
#   'date': '2021-08-28T00:00:00',
#   'icu_unvac': 89,
#   'icu_partial_vac': 7,
#   'icu_full_vac': 8,
#   'hospitalnonicu_unvac': 149,
#   'hospitalnonicu_partial_vac': 19,
#   'hospitalnonicu_full_vac': 30},
#  {'_id': 20,
#   'date': '2021-08-29T00:00:00',
#   'icu_unvac': 69,
#   'icu_partial_vac': 9,
#   'icu_full_vac': 11,
#   'hospitalnonicu_unvac': 119,
#   'hospitalnonicu_partial_vac': 15,
#   'hospitalnonicu_full_vac': 35},
#  {'_id': 21,
#   'date': '2021-08-30T00:00:00',
#   'icu_unvac': 72,
#   'icu_partial_vac': 8,
#   'icu_full_vac': 11,
#   'hospitalnonicu_unvac': 118,
#   'hospitalnonicu_partial_vac': 13,
#   'hospitalnonicu_full_vac': 35},
#  {'_id': 22,
#   'date': '2021-08-31T00:00:00',
#   'icu_unvac': 87,
#   'icu_partial_vac': 8,
#   'icu_full_vac': 10,
#   'hospitalnonicu_unvac': 152,
#   'hospitalnonicu_partial_vac': 19,
#   'hospitalnonicu_full_vac': 34},
#  {'_id': 23,
#   'date': '2021-09-01T00:00:00',
#   'icu_unvac': 93,
#   'icu_partial_vac': 6,
#   'icu_full_vac': 11,
#   'hospitalnonicu_unvac': 163,
#   'hospitalnonicu_partial_vac': 14,
#   'hospitalnonicu_full_vac': 37},
#  {'_id': 24,
#   'date': '2021-09-02T00:00:00',
#   'icu_unvac': 90,
#   'icu_partial_vac': 8,
#   'icu_full_vac': 14,
#   'hospitalnonicu_unvac': 143,
#   'hospitalnonicu_partial_vac': 12,
#   'hospitalnonicu_full_vac': 28},
#  {'_id': 25,
#   'date': '2021-09-03T00:00:00',
#   'icu_unvac': 103,
#   'icu_partial_vac': 8,
#   'icu_full_vac': 12,
#   'hospitalnonicu_unvac': 145,
#   'hospitalnonicu_partial_vac': 17,
#   'hospitalnonicu_full_vac': 34},
#  {'_id': 26,
#   'date': '2021-09-04T00:00:00',
#   'icu_unvac': 106,
#   'icu_partial_vac': 7,
#   'icu_full_vac': 12,
#   'hospitalnonicu_unvac': 153,
#   'hospitalnonicu_partial_vac': 16,
#   'hospitalnonicu_full_vac': 33},
#  {'_id': 27,
#   'date': '2021-09-05T00:00:00',
#   'icu_unvac': 94,
#   'icu_partial_vac': 7,
#   'icu_full_vac': 13,
#   'hospitalnonicu_unvac': 129,
#   'hospitalnonicu_partial_vac': 13,
#   'hospitalnonicu_full_vac': 28},
#  {'_id': 28,
#   'date': '2021-09-06T00:00:00',
#   'icu_unvac': 93,
#   'icu_partial_vac': 7,
#   'icu_full_vac': 12,
#   'hospitalnonicu_unvac': 136,
#   'hospitalnonicu_partial_vac': 14,
#   'hospitalnonicu_full_vac': 25},
#  {'_id': 29,
#   'date': '2021-09-07T00:00:00',
#   'icu_unvac': 94,
#   'icu_partial_vac': 5,
#   'icu_full_vac': 9,
#   'hospitalnonicu_unvac': 135,
#   'hospitalnonicu_partial_vac': 13,
#   'hospitalnonicu_full_vac': 32},
#  {'_id': 30,
#   'date': '2021-09-08T00:00:00',
#   'icu_unvac': 114,
#   'icu_partial_vac': 7,
#   'icu_full_vac': 8,
#   'hospitalnonicu_unvac': 162,
#   'hospitalnonicu_partial_vac': 14,
#   'hospitalnonicu_full_vac': 28},
#  {'_id': 31,
#   'date': '2021-09-09T00:00:00',
#   'icu_unvac': 108,
#   'icu_partial_vac': 8,
#   'icu_full_vac': 11,
#   'hospitalnonicu_unvac': 149,
#   'hospitalnonicu_partial_vac': 9,
#   'hospitalnonicu_full_vac': 34},
#  {'_id': 32,
#   'date': '2021-09-10T00:00:00',
#   'icu_unvac': 112,
#   'icu_partial_vac': 9,
#   'icu_full_vac': 14,
#   'hospitalnonicu_unvac': 163,
#   'hospitalnonicu_partial_vac': 18,
#   'hospitalnonicu_full_vac': 31},
#  {'_id': 33,
#   'date': '2021-09-11T00:00:00',
#   'icu_unvac': 103,
#   'icu_partial_vac': 8,
#   'icu_full_vac': 15,
#   'hospitalnonicu_unvac': 159,
#   'hospitalnonicu_partial_vac': 12,
#   'hospitalnonicu_full_vac': 42},
#  {'_id': 34,
#   'date': '2021-09-12T00:00:00',
#   'icu_unvac': 87,
#   'icu_partial_vac': 9,
#   'icu_full_vac': 12,
#   'hospitalnonicu_unvac': 141,
#   'hospitalnonicu_partial_vac': 11,
#   'hospitalnonicu_full_vac': 33},
#  {'_id': 35,
#   'date': '2021-09-13T00:00:00',
#   'icu_unvac': 78,
#   'icu_partial_vac': 7,
#   'icu_full_vac': 10,
#   'hospitalnonicu_unvac': 126,
#   'hospitalnonicu_partial_vac': 9,
#   'hospitalnonicu_full_vac': 28},
#  {'_id': 36,
#   'date': '2021-09-14T00:00:00',
#   'icu_unvac': 108,
#   'icu_partial_vac': 9,
#   'icu_full_vac': 9,
#   'hospitalnonicu_unvac': 146,
#   'hospitalnonicu_partial_vac': 8,
#   'hospitalnonicu_full_vac': 40},
#  {'_id': 37,
#   'date': '2021-09-15T00:00:00',
#   'icu_unvac': 117,
#   'icu_partial_vac': 10,
#   'icu_full_vac': 10,
#   'hospitalnonicu_unvac': 148,
#   'hospitalnonicu_partial_vac': 7,
#   'hospitalnonicu_full_vac': 35},
#  {'_id': 38,
#   'date': '2021-09-16T00:00:00',
#   'icu_unvac': 118,
#   'icu_partial_vac': 10,
#   'icu_full_vac': 13,
#   'hospitalnonicu_unvac': 150,
#   'hospitalnonicu_partial_vac': 9,
#   'hospitalnonicu_full_vac': 30},
#  {'_id': 39,
#   'date': '2021-09-17T00:00:00',
#   'icu_unvac': 120,
#   'icu_partial_vac': 9,
#   'icu_full_vac': 13,
#   'hospitalnonicu_unvac': 135,
#   'hospitalnonicu_partial_vac': 10,
#   'hospitalnonicu_full_vac': 32},
#  {'_id': 40,
#   'date': '2021-09-18T00:00:00',
#   'icu_unvac': 116,
#   'icu_partial_vac': 10,
#   'icu_full_vac': 11,
#   'hospitalnonicu_unvac': 132,
#   'hospitalnonicu_partial_vac': 10,
#   'hospitalnonicu_full_vac': 35},
#  {'_id': 41,
#   'date': '2021-09-19T00:00:00',
#   'icu_unvac': 99,
#   'icu_partial_vac': 7,
#   'icu_full_vac': 10,
#   'hospitalnonicu_unvac': 100,
#   'hospitalnonicu_partial_vac': 11,
#   'hospitalnonicu_full_vac': 35},
#  {'_id': 42,
#   'date': '2021-09-20T00:00:00',
#   'icu_unvac': 98,
#   'icu_partial_vac': 8,
#   'icu_full_vac': 7,
#   'hospitalnonicu_unvac': 104,
#   'hospitalnonicu_partial_vac': 8,
#   'hospitalnonicu_full_vac': 30},
#  {'_id': 43,
#   'date': '2021-09-21T00:00:00',
#   'icu_unvac': 109,
#   'icu_partial_vac': 9,
#   'icu_full_vac': 9,
#   'hospitalnonicu_unvac': 118,
#   'hospitalnonicu_partial_vac': 11,
#   'hospitalnonicu_full_vac': 29},
#  {'_id': 44,
#   'date': '2021-09-22T00:00:00',
#   'icu_unvac': 102,
#   'icu_partial_vac': 10,
#   'icu_full_vac': 9,
#   'hospitalnonicu_unvac': 123,
#   'hospitalnonicu_partial_vac': 8,
#   'hospitalnonicu_full_vac': 28},
#  {'_id': 45,
#   'date': '2021-09-23T00:00:00',
#   'icu_unvac': 108,
#   'icu_partial_vac': 12,
#   'icu_full_vac': 12,
#   'hospitalnonicu_unvac': 117,
#   'hospitalnonicu_partial_vac': 9,
#   'hospitalnonicu_full_vac': 33},
#  {'_id': 46,
#   'date': '2021-09-24T00:00:00',
#   'icu_unvac': 110,
#   'icu_partial_vac': 11,
#   'icu_full_vac': 11,
#   'hospitalnonicu_unvac': 120,
#   'hospitalnonicu_partial_vac': 10,
#   'hospitalnonicu_full_vac': 38},
#  {'_id': 47,
#   'date': '2021-09-25T00:00:00',
#   'icu_unvac': 105,
#   'icu_partial_vac': 11,
#   'icu_full_vac': 7,
#   'hospitalnonicu_unvac': 129,
#   'hospitalnonicu_partial_vac': 9,
#   'hospitalnonicu_full_vac': 42},
#  {'_id': 48,
#   'date': '2021-09-26T00:00:00',
#   'icu_unvac': 95,
#   'icu_partial_vac': 9,
#   'icu_full_vac': 6,
#   'hospitalnonicu_unvac': 105,
#   'hospitalnonicu_partial_vac': 6,
#   'hospitalnonicu_full_vac': 41},
#  {'_id': 49,
#   'date': '2021-09-27T00:00:00',
#   'icu_unvac': 85,
#   'icu_partial_vac': 7,
#   'icu_full_vac': 7,
#   'hospitalnonicu_unvac': 104,
#   'hospitalnonicu_partial_vac': 6,
#   'hospitalnonicu_full_vac': 39},
#  {'_id': 50,
#   'date': '2021-09-28T00:00:00',
#   'icu_unvac': 107,
#   'icu_partial_vac': 9,
#   'icu_full_vac': 8,
#   'hospitalnonicu_unvac': 116,
#   'hospitalnonicu_partial_vac': 8,
#   'hospitalnonicu_full_vac': 38},
#  {'_id': 51,
#   'date': '2021-09-29T00:00:00',
#   'icu_unvac': 99,
#   'icu_partial_vac': 10,
#   'icu_full_vac': 8,
#   'hospitalnonicu_unvac': 123,
#   'hospitalnonicu_partial_vac': 7,
#   'hospitalnonicu_full_vac': 32},
#  {'_id': 52,
#   'date': '2021-09-30T00:00:00',
#   'icu_unvac': 93,
#   'icu_partial_vac': 10,
#   'icu_full_vac': 8,
#   'hospitalnonicu_unvac': 125,
#   'hospitalnonicu_partial_vac': 10,
#   'hospitalnonicu_full_vac': 32},
#  {'_id': 53,
#   'date': '2021-10-01T00:00:00',
#   'icu_unvac': 94,
#   'icu_partial_vac': 8,
#   'icu_full_vac': 7,
#   'hospitalnonicu_unvac': 115,
#   'hospitalnonicu_partial_vac': 10,
#   'hospitalnonicu_full_vac': 28},
#  {'_id': 54,
#   'date': '2021-10-02T00:00:00',
#   'icu_unvac': 94,
#   'icu_partial_vac': 8,
#   'icu_full_vac': 7,
#   'hospitalnonicu_unvac': 115,
#   'hospitalnonicu_partial_vac': 8,
#   'hospitalnonicu_full_vac': 31},
#  {'_id': 55,
#   'date': '2021-10-03T00:00:00',
#   'icu_unvac': 84,
#   'icu_partial_vac': 6,
#   'icu_full_vac': 8,
#   'hospitalnonicu_unvac': 95,
#   'hospitalnonicu_partial_vac': 10,
#   'hospitalnonicu_full_vac': 28},
#  {'_id': 56,
#   'date': '2021-10-04T00:00:00',
#   'icu_unvac': 77,
#   'icu_partial_vac': 6,
#   'icu_full_vac': 8,
#   'hospitalnonicu_unvac': 96,
#   'hospitalnonicu_partial_vac': 10,
#   'hospitalnonicu_full_vac': 26},
#  {'_id': 57,
#   'date': '2021-10-05T00:00:00',
#   'icu_unvac': 78,
#   'icu_partial_vac': 8,
#   'icu_full_vac': 8,
#   'hospitalnonicu_unvac': 106,
#   'hospitalnonicu_partial_vac': 8,
#   'hospitalnonicu_full_vac': 41},
#  {'_id': 58,
#   'date': '2021-10-06T00:00:00',
#   'icu_unvac': 75,
#   'icu_partial_vac': 7,
#   'icu_full_vac': 12,
#   'hospitalnonicu_unvac': 121,
#   'hospitalnonicu_partial_vac': 11,
#   'hospitalnonicu_full_vac': 46},
#  {'_id': 59,
#   'date': '2021-10-07T00:00:00',
#   'icu_unvac': 74,
#   'icu_partial_vac': 10,
#   'icu_full_vac': 14,
#   'hospitalnonicu_unvac': 95,
#   'hospitalnonicu_partial_vac': 12,
#   'hospitalnonicu_full_vac': 49},
#  {'_id': 60,
#   'date': '2021-10-08T00:00:00',
#   'icu_unvac': 73,
#   'icu_partial_vac': 11,
#   'icu_full_vac': 14,
#   'hospitalnonicu_unvac': 104,
#   'hospitalnonicu_partial_vac': 11,
#   'hospitalnonicu_full_vac': 41},
#  {'_id': 61,
#   'date': '2021-10-09T00:00:00',
#   'icu_unvac': 64,
#   'icu_partial_vac': 6,
#   'icu_full_vac': 14,
#   'hospitalnonicu_unvac': 92,
#   'hospitalnonicu_partial_vac': 12,
#   'hospitalnonicu_full_vac': 38},
#  {'_id': 62,
#   'date': '2021-10-10T00:00:00',
#   'icu_unvac': 59,
#   'icu_partial_vac': 6,
#   'icu_full_vac': 16,
#   'hospitalnonicu_unvac': 89,
#   'hospitalnonicu_partial_vac': 6,
#   'hospitalnonicu_full_vac': 36},
#  {'_id': 63,
#   'date': '2021-10-11T00:00:00',
#   'icu_unvac': 64,
#   'icu_partial_vac': 6,
#   'icu_full_vac': 16,
#   'hospitalnonicu_unvac': 86,
#   'hospitalnonicu_partial_vac': 6,
#   'hospitalnonicu_full_vac': 36},
#  {'_id': 64,
#   'date': '2021-10-12T00:00:00',
#   'icu_unvac': 70,
#   'icu_partial_vac': 6,
#   'icu_full_vac': 22,
#   'hospitalnonicu_unvac': 95,
#   'hospitalnonicu_partial_vac': 9,
#   'hospitalnonicu_full_vac': 34},
#  {'_id': 65,
#   'date': '2021-10-13T00:00:00',
#   'icu_unvac': 68,
#   'icu_partial_vac': 6,
#   'icu_full_vac': 14,
#   'hospitalnonicu_unvac': 100,
#   'hospitalnonicu_partial_vac': 11,
#   'hospitalnonicu_full_vac': 33},
#  {'_id': 66,
#   'date': '2021-10-14T00:00:00',
#   'icu_unvac': 80,
#   'icu_partial_vac': 6,
#   'icu_full_vac': 13,
#   'hospitalnonicu_unvac': 99,
#   'hospitalnonicu_partial_vac': 13,
#   'hospitalnonicu_full_vac': 35},
#  {'_id': 67,
#   'date': '2021-10-15T00:00:00',
#   'icu_unvac': 82,
#   'icu_partial_vac': 7,
#   'icu_full_vac': 16,
#   'hospitalnonicu_unvac': 97,
#   'hospitalnonicu_partial_vac': 10,
#   'hospitalnonicu_full_vac': 39},
#  {'_id': 68,
#   'date': '2021-10-16T00:00:00',
#   'icu_unvac': 77,
#   'icu_partial_vac': 3,
#   'icu_full_vac': 18,
#   'hospitalnonicu_unvac': 100,
#   'hospitalnonicu_partial_vac': 9,
#   'hospitalnonicu_full_vac': 32},
#  {'_id': 69,
#   'date': '2021-10-17T00:00:00',
#   'icu_unvac': 79,
#   'icu_partial_vac': 5,
#   'icu_full_vac': 21,
#   'hospitalnonicu_unvac': 99,
#   'hospitalnonicu_partial_vac': 8,
#   'hospitalnonicu_full_vac': 36},
#  {'_id': 70,
#   'date': '2021-10-18T00:00:00',
#   'icu_unvac': 77,
#   'icu_partial_vac': 5,
#   'icu_full_vac': 22,
#   'hospitalnonicu_unvac': 92,
#   'hospitalnonicu_partial_vac': 8,
#   'hospitalnonicu_full_vac': 36},
#  {'_id': 71,
#   'date': '2021-10-19T00:00:00',
#   'icu_unvac': 79,
#   'icu_partial_vac': 4,
#   'icu_full_vac': 26,
#   'hospitalnonicu_unvac': 106,
#   'hospitalnonicu_partial_vac': 11,
#   'hospitalnonicu_full_vac': 37},
#  {'_id': 72,
#   'date': '2021-10-20T00:00:00',
#   'icu_unvac': 79,
#   'icu_partial_vac': 6,
#   'icu_full_vac': 22,
#   'hospitalnonicu_unvac': 116,
#   'hospitalnonicu_partial_vac': 11,
#   'hospitalnonicu_full_vac': 31},
#  {'_id': 73,
#   'date': '2021-10-21T00:00:00',
#   'icu_unvac': 73,
#   'icu_partial_vac': 7,
#   'icu_full_vac': 20,
#   'hospitalnonicu_unvac': 129,
#   'hospitalnonicu_partial_vac': 8,
#   'hospitalnonicu_full_vac': 39},
#  {'_id': 74,
#   'date': '2021-10-22T00:00:00',
#   'icu_unvac': 75,
#   'icu_partial_vac': 8,
#   'icu_full_vac': 21,
#   'hospitalnonicu_unvac': 116,
#   'hospitalnonicu_partial_vac': 12,
#   'hospitalnonicu_full_vac': 36},
#  {'_id': 75,
#   'date': '2021-10-23T00:00:00',
#   'icu_unvac': 72,
#   'icu_partial_vac': 6,
#   'icu_full_vac': 16,
#   'hospitalnonicu_unvac': 119,
#   'hospitalnonicu_partial_vac': 13,
#   'hospitalnonicu_full_vac': 38},
#  {'_id': 76,
#   'date': '2021-10-24T00:00:00',
#   'icu_unvac': 63,
#   'icu_partial_vac': 5,
#   'icu_full_vac': 17,
#   'hospitalnonicu_unvac': 122,
#   'hospitalnonicu_partial_vac': 15,
#   'hospitalnonicu_full_vac': 36},
#  {'_id': 77,
#   'date': '2021-10-25T00:00:00',
#   'icu_unvac': 59,
#   'icu_partial_vac': 5,
#   'icu_full_vac': 21,
#   'hospitalnonicu_unvac': 120,
#   'hospitalnonicu_partial_vac': 13,
#   'hospitalnonicu_full_vac': 36},
#  {'_id': 78,
#   'date': '2021-10-26T00:00:00',
#   'icu_unvac': 63,
#   'icu_partial_vac': 5,
#   'icu_full_vac': 17,
#   'hospitalnonicu_unvac': 111,
#   'hospitalnonicu_partial_vac': 14,
#   'hospitalnonicu_full_vac': 33},
#  {'_id': 79,
#   'date': '2021-10-27T00:00:00',
#   'icu_unvac': 65,
#   'icu_partial_vac': 7,
#   'icu_full_vac': 19,
#   'hospitalnonicu_unvac': 96,
#   'hospitalnonicu_partial_vac': 13,
#   'hospitalnonicu_full_vac': 30},
#  {'_id': 80,
#   'date': '2021-10-28T00:00:00',
#   'icu_unvac': 62,
#   'icu_partial_vac': 8,
#   'icu_full_vac': 16,
#   'hospitalnonicu_unvac': 94,
#   'hospitalnonicu_partial_vac': 12,
#   'hospitalnonicu_full_vac': 30},
#  {'_id': 81,
#   'date': '2021-10-29T00:00:00',
#   'icu_unvac': 64,
#   'icu_partial_vac': 8,
#   'icu_full_vac': 14,
#   'hospitalnonicu_unvac': 100,
#   'hospitalnonicu_partial_vac': 12,
#   'hospitalnonicu_full_vac': 32},
#  {'_id': 82,
#   'date': '2021-10-30T00:00:00',
#   'icu_unvac': 72,
#   'icu_partial_vac': 5,
#   'icu_full_vac': 15,
#   'hospitalnonicu_unvac': 91,
#   'hospitalnonicu_partial_vac': 13,
#   'hospitalnonicu_full_vac': 39},
#  {'_id': 83,
#   'date': '2021-10-31T00:00:00',
#   'icu_unvac': 48,
#   'icu_partial_vac': 3,
#   'icu_full_vac': 14,
#   'hospitalnonicu_unvac': 95,
#   'hospitalnonicu_partial_vac': 9,
#   'hospitalnonicu_full_vac': 45},
#  {'_id': 84,
#   'date': '2021-11-01T00:00:00',
#   'icu_unvac': 62,
#   'icu_partial_vac': 7,
#   'icu_full_vac': 13,
#   'hospitalnonicu_unvac': 93,
#   'hospitalnonicu_partial_vac': 12,
#   'hospitalnonicu_full_vac': 45},
#  {'_id': 85,
#   'date': '2021-11-02T00:00:00',
#   'icu_unvac': 67,
#   'icu_partial_vac': 5,
#   'icu_full_vac': 16,
#   'hospitalnonicu_unvac': 96,
#   'hospitalnonicu_partial_vac': 14,
#   'hospitalnonicu_full_vac': 49},
#  {'_id': 86,
#   'date': '2021-11-03T00:00:00',
#   'icu_unvac': 66,
#   'icu_partial_vac': 6,
#   'icu_full_vac': 14,
#   'hospitalnonicu_unvac': 82,
#   'hospitalnonicu_partial_vac': 13,
#   'hospitalnonicu_full_vac': 64},
#  {'_id': 87,
#   'date': '2021-11-04T00:00:00',
#   'icu_unvac': 64,
#   'icu_partial_vac': 5,
#   'icu_full_vac': 16,
#   'hospitalnonicu_unvac': 78,
#   'hospitalnonicu_partial_vac': 11,
#   'hospitalnonicu_full_vac': 60},
#  {'_id': 88,
#   'date': '2021-11-05T00:00:00',
#   'icu_unvac': 59,
#   'icu_partial_vac': 2,
#   'icu_full_vac': 12,
#   'hospitalnonicu_unvac': 83,
#   'hospitalnonicu_partial_vac': 12,
#   'hospitalnonicu_full_vac': 59},
#  {'_id': 89,
#   'date': '2021-11-06T00:00:00',
#   'icu_unvac': 56,
#   'icu_partial_vac': 3,
#   'icu_full_vac': 16,
#   'hospitalnonicu_unvac': 81,
#   'hospitalnonicu_partial_vac': 14,
#   'hospitalnonicu_full_vac': 55},
#  {'_id': 90,
#   'date': '2021-11-07T00:00:00',
#   'icu_unvac': 51,
#   'icu_partial_vac': 3,
#   'icu_full_vac': 15,
#   'hospitalnonicu_unvac': 74,
#   'hospitalnonicu_partial_vac': 12,
#   'hospitalnonicu_full_vac': 52},
#  {'_id': 91,
#   'date': '2021-11-08T00:00:00',
#   'icu_unvac': 52,
#   'icu_partial_vac': 2,
#   'icu_full_vac': 15,
#   'hospitalnonicu_unvac': 77,
#   'hospitalnonicu_partial_vac': 10,
#   'hospitalnonicu_full_vac': 59},
#  {'_id': 92,
#   'date': '2021-11-09T00:00:00',
#   'icu_unvac': 54,
#   'icu_partial_vac': 3,
#   'icu_full_vac': 20,
#   'hospitalnonicu_unvac': 82,
#   'hospitalnonicu_partial_vac': 9,
#   'hospitalnonicu_full_vac': 72},
#  {'_id': 93,
#   'date': '2021-11-10T00:00:00',
#   'icu_unvac': 56,
#   'icu_partial_vac': 4,
#   'icu_full_vac': 16,
#   'hospitalnonicu_unvac': 76,
#   'hospitalnonicu_partial_vac': 12,
#   'hospitalnonicu_full_vac': 61},
#  {'_id': 94,
#   'date': '2021-11-11T00:00:00',
#   'icu_unvac': 62,
#   'icu_partial_vac': 4,
#   'icu_full_vac': 18,
#   'hospitalnonicu_unvac': 90,
#   'hospitalnonicu_partial_vac': 15,
#   'hospitalnonicu_full_vac': 67},
#  {'_id': 95,
#   'date': '2021-11-12T00:00:00',
#   'icu_unvac': 65,
#   'icu_partial_vac': 4,
#   'icu_full_vac': 13,
#   'hospitalnonicu_unvac': 90,
#   'hospitalnonicu_partial_vac': 18,
#   'hospitalnonicu_full_vac': 71},
#  {'_id': 96,
#   'date': '2021-11-13T00:00:00',
#   'icu_unvac': 66,
#   'icu_partial_vac': 3,
#   'icu_full_vac': 15,
#   'hospitalnonicu_unvac': 81,
#   'hospitalnonicu_partial_vac': 16,
#   'hospitalnonicu_full_vac': 74},
#  {'_id': 97,
#   'date': '2021-11-14T00:00:00',
#   'icu_unvac': 62,
#   'icu_partial_vac': 5,
#   'icu_full_vac': 16,
#   'hospitalnonicu_unvac': 87,
#   'hospitalnonicu_partial_vac': 17,
#   'hospitalnonicu_full_vac': 78},
#  {'_id': 98,
#   'date': '2021-11-15T00:00:00',
#   'icu_unvac': 62,
#   'icu_partial_vac': 3,
#   'icu_full_vac': 18,
#   'hospitalnonicu_unvac': 102,
#   'hospitalnonicu_partial_vac': 18,
#   'hospitalnonicu_full_vac': 81},
#  {'_id': 99,
#   'date': '2021-11-16T00:00:00',
#   'icu_unvac': 64,
#   'icu_partial_vac': 4,
#   'icu_full_vac': 19,
#   'hospitalnonicu_unvac': 102,
#   'hospitalnonicu_partial_vac': 17,
#   'hospitalnonicu_full_vac': 76},
#  {'_id': 100,
#   'date': '2021-11-17T00:00:00',
#   'icu_unvac': 62,
#   'icu_partial_vac': 5,
#   'icu_full_vac': 19,
#   'hospitalnonicu_unvac': 92,
#   'hospitalnonicu_partial_vac': 16,
#   'hospitalnonicu_full_vac': 70}]

# %%
hos_by_vac = pd.DataFrame(data['result']['records'])
hos_by_vac
# Out:
#     _id                 date  icu_unvac  icu_partial_vac  icu_full_vac  \
# 0     1  2021-08-10T00:00:00         22                3             0
# 1     2  2021-08-11T00:00:00         37                5             2
# 2     3  2021-08-12T00:00:00         45                5             2
# 3     4  2021-08-13T00:00:00         52                5             3
# 4     5  2021-08-14T00:00:00         53                4             1
# ..  ...                  ...        ...              ...           ...
# 95   96  2021-11-13T00:00:00         66                3            15
# 96   97  2021-11-14T00:00:00         62                5            16
# 97   98  2021-11-15T00:00:00         62                3            18
# 98   99  2021-11-16T00:00:00         64                4            19
# 99  100  2021-11-17T00:00:00         62                5            19
#
#     hospitalnonicu_unvac  hospitalnonicu_partial_vac  hospitalnonicu_full_vac
# 0                     23                           4                       11
# 1                     34                           7                        8
# 2                     44                           7                        9
# 3                     65                           6                        8
# 4                     67                           6                       11
# ..                   ...                         ...                      ...
# 95                    81                          16                       74
# 96                    87                          17                       78
# 97                   102                          18                       81
# 98                   102                          17                       76
# 99                    92                          16                       70
#
# [100 rows x 8 columns]

# %%
# Q8. Illustrate your Data Cleaning and Feature Engineering processes A: no missing value 


#check missing value
hos_by_vac.isna().sum() 
#the data has no missing value, so no further data cleaning is needed.
# Out:
# _id                           0
# date                          0
# icu_unvac                     0
# icu_partial_vac               0
# icu_full_vac                  0
# hospitalnonicu_unvac          0
# hospitalnonicu_partial_vac    0
# hospitalnonicu_full_vac       0
# dtype: int64

# %%
#convert time to datetime object
hos_by_vac['date'] = pd.to_datetime(hos_by_vac['date'])
#sum up the icu total visits
hos_by_vac['total_icu_visit'] = hos_by_vac['icu_unvac']+hos_by_vac['icu_partial_vac']+hos_by_vac['icu_full_vac']

hos_by_vac.head()
# Out:
#    _id       date  icu_unvac  icu_partial_vac  icu_full_vac  \
# 0    1 2021-08-10         22                3             0
# 1    2 2021-08-11         37                5             2
# 2    3 2021-08-12         45                5             2
# 3    4 2021-08-13         52                5             3
# 4    5 2021-08-14         53                4             1
#
#    hospitalnonicu_unvac  hospitalnonicu_partial_vac  hospitalnonicu_full_vac  \
# 0                    23                           4                       11
# 1                    34                           7                        8
# 2                    44                           7                        9
# 3                    65                           6                        8
# 4                    67                           6                       11
#
#    total_icu_visit
# 0               25
# 1               44
# 2               52
# 3               60
# 4               58

# %%
# Q8. Illustrate your Data Cleaning and Feature Engineering processes

# accumulate the total visit of icu since 2021/08/10
hos_by_vac['accu_icu_visits'] = 0
for i in range(len(hos_by_vac['date'])):
    if i == 0:
        hos_by_vac.loc[i, 'accu_icu_visits'] = hos_by_vac.loc[i, 'total_icu_visit']
    else:
        hos_by_vac.loc[i, 'accu_icu_visits'] = hos_by_vac.loc[i, 'total_icu_visit'] +\
        hos_by_vac.loc[i-1, 'total_icu_visit']
hos_by_vac
# Out:
#     _id       date  icu_unvac  icu_partial_vac  icu_full_vac  \
# 0     1 2021-08-10         22                3             0
# 1     2 2021-08-11         37                5             2
# 2     3 2021-08-12         45                5             2
# 3     4 2021-08-13         52                5             3
# 4     5 2021-08-14         53                4             1
# ..  ...        ...        ...              ...           ...
# 95   96 2021-11-13         66                3            15
# 96   97 2021-11-14         62                5            16
# 97   98 2021-11-15         62                3            18
# 98   99 2021-11-16         64                4            19
# 99  100 2021-11-17         62                5            19
#
#     hospitalnonicu_unvac  hospitalnonicu_partial_vac  hospitalnonicu_full_vac  \
# 0                     23                           4                       11
# 1                     34                           7                        8
# 2                     44                           7                        9
# 3                     65                           6                        8
# 4                     67                           6                       11
# ..                   ...                         ...                      ...
# 95                    81                          16                       74
# 96                    87                          17                       78
# 97                   102                          18                       81
# 98                   102                          17                       76
# 99                    92                          16                       70
#
#     total_icu_visit  accu_icu_visits
# 0                25               25
# 1                44               69
# 2                52               96
# 3                60              112
# 4                58              118
# ..              ...              ...
# 95               84              166
# 96               83              167
# 97               83              166
# 98               87              170
# 99               86              173
#
# [100 rows x 10 columns]

# %%
import pandas as pd
import sqlalchemy as sa
from sqlalchemy import create_engine, types

# %%
# Q7. Write a function to request the data

# preparing the data importing to SQL database 


db_secret = {
    "drivername": "postgresql+psycopg2",
    "host": "mmai5100postgres.canadacentral.cloudapp.azure.com",
    "port": 5432,
    "database": "hungchi",
    "user": "hungchi",
    "password": "2022!Schulich",
}

def create_db_engine(**args):
    
    connection_url = sa.engine.URL.create(
        drivername = args.pop("drivername"),
        username   = args.pop("user"),
        password   = args.pop("password"),
        host       = args.pop("host"),
        port       = args.pop("port"),
        database   = args.pop("database") if 'database' in args else ''
    )
    
    engine = sa.create_engine(connection_url, **args)
    
    return engine

engine = create_db_engine(**db_secret)

# %%
# db_url = "postgresql+psycopg2://hungchi:2022!Schulich@mmai5100postgres.canadacentral.cloudapp.azure.com:5432/hungchi"
# engine = create_engine(db_url)

# %%
# building the connection
conection= engine.connect()
conection.execute('CREATE SCHEMA IF NOT EXISTS dimensions')
conection.close()

# %%
# Q9. Ingest the data into your own database in our PostgreSQL server

#import data
hos_by_vac.to_sql(
    name= 'icu_cases', 
    con= engine,
    schema= 'dimensions', 
    if_exists= 'replace',
    index= False, 
    dtype= {
        'date':types.DATE, 
        'new_cases': types.DECIMAL(10,0)
    },
method= 'multi'


)
